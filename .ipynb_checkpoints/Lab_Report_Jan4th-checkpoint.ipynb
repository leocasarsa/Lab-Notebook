# %% [markdown]
# ## Simple Additive Noise Model
#
# $W \leftarrow \mathcal{N}(5,1)$
#
# $Z \leftarrow \mathcal{N}(-5,2)$
#
# $X \leftarrow W + Z + \mathcal{N}(0,1)$
#
# $Y \leftarrow X - 2 \times Z + \mathcal{N}(0,1)$

# %%
# %matplotlib inline
from matplotlib import cm
import matplotlib.pyplot as plt

import scipy as sp
import scipy.stats as sts
import numpy as np


n_samples = 1000

W = sts.norm.rvs(loc=5, scale = 1, size = [n_samples,1])
Z = sts.norm.rvs(loc=-5, scale = 2, size = [n_samples,1])
X = W + Z + sts.norm.rvs(loc=0, scale = 1, size = [n_samples,1])
Y = X - 2*Z + sts.norm.rvs(loc=0, scale = 1, size = [n_samples,1])

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

sc = axes.scatter(X,Y, s=20,c=Z, marker = 'o', cmap = cm.jet )
plt.colorbar(sc)

axes.set_ylabel('Y')
axes.set_xlabel('X')
axes.set_title('Color: Z')

# %% [markdown]
# ## Regression coefficients with control

# %%
from sklearn import linear_model

x_pred = np.arange(-10,10,0.1).reshape(-1,1)

# Simple Linear Regression
regr = linear_model.LinearRegression()
regr.fit(X,Y)
b_x = regr.coef_
y_pred_x = regr.predict(x_pred)

# Multiple Linear Regression (controlled for Z)
regr = linear_model.LinearRegression()
regr.fit(np.hstack((X,Z)),Y)
b_x_gZ = regr.coef_
# y_pred_x_gZ = regr.predict(x_pred)

# Multiple Linear Regression (controlled for W,Z)
regr = linear_model.LinearRegression()
regr.fit(np.hstack((X,W,Z)),Y)
b_x_gZW = regr.coef_
# y_pred_x_gZW = regr.predict(x_pred)

# %% [markdown]
# # CMI
# ## Convert data to csv

# %%
import pandas as pd

# Convert data to dataframe
data = np.hstack((X,Y,W,Z))
header = np.array(['X','Y','W','Z'])
df = pd.DataFrame(data, columns = header)

# Check scatterplot
df.plot(kind='scatter',x='X', y='Y', s=20, c='Z', marker = 'o', cmap = cm.jet)

# Convert to csv
filename = 'lineargaussian.csv'
df.to_csv(filename)

# %% [markdown]
# ## Analytic CMIs
#
# $X,Y,W,Z \sim \mathcal{N} ({\mu}, \Sigma)$
#
# $CMI(X;Y|Z) = \frac{1}{2} \log (\frac{|\Sigma_{XZ}| |\Sigma_{YZ}|} {|\Sigma_{XYZ}|\sigma^2_{Z}})$
#
# $CMI(X;Y|Z, W) = \frac{1}{2} \log (\frac{|\Sigma_{XWZ}| |\Sigma_{YWZ}|} {|\Sigma_{XYWZ}||\Sigma_{WZ}|})$

# %%
def CMI(Sigma,X,Y,givens):
    '''Compute CMI(X;Y|givens) for {X,Y,givens} jointly gaussian distributed
        Sigma - multivariate covariance matrix
        X - column index of first target
        Y - column index of second target
        givens - list of column indexes of variables to condition on
    ''' 
    Sigma_Xgivens = submatrix(Sigma,[X] + givens)
    Sigma_Ygivens = submatrix(Sigma,[Y] + givens)
    Sigma_tot = submatrix(Sigma, [X,Y] + givens)
    Sigma_givens = submatrix(Sigma,givens)

    return .5*np.log( det(Sigma_Xgivens) * det(Sigma_Ygivens) / (det(Sigma_tot) * det(Sigma_givens) ))

print CMI(Sigma,0,1,[3])

def alt_CMI(Sigma, X, Y, givens):
    '''
    
    '''
    Sigma_Xbargivens = conditional_cov(Sigma, [X], givens)
    Sigma_Ybargivens = conditional_cov(Sigma, [Y], givens)
    Sigma_XYbargivens = conditional_cov(Sigma, [X,Y], givens)
    
    return - .5 * np.log( det(Sigma_XYbargivens) / (det(Sigma_Xbargivens)* det(Sigma_Ybargivens)))

print alt_CMI(Sigma,0,1,[3])
# Out:
# 0.549306144334
# 0.549306144334

# %%
from numpy.linalg import det

#                X=0, Y=1, W=2, Z=3
#                 [ X, Y,W, Z] 
Sigma = np.array([[ 6,-2,1, 4],
                  [-2, 7,1,-4],
                  [ 1, 1,1, 0],
                  [ 4,-4,0, 4]])

Sigma_XYZ = Sigma[np.ix_([0,1,3],[0,1,3])]
Sigma_XWZ = Sigma[np.ix_([0,2,3],[0,2,3])]
Sigma_YWZ = Sigma[1:,1:]

Sigma_XY = Sigma[np.ix_([0,1],[0,1])]
Sigma_XZ = Sigma[np.ix_([0,3],[0,3])]
Sigma_YZ = Sigma[np.ix_([1,3],[1,3])]
Sigma_WZ = Sigma[2:,2:]

sigma_Z = Sigma[3,3]

CMI_XYZ = .5 * np.log( det(Sigma_XZ)*det(Sigma_YZ) / (det(Sigma_XYZ)*sigma_Z) )
CMI_XYZW = .5 * np.log( det(Sigma_XWZ)*det(Sigma_YWZ) / (det(Sigma)*det(Sigma_WZ)) )

# %% [markdown]
# ### Conditional Covariance Matrices
# $\Sigma_{XY|Z} = \Sigma_{XY}-\Sigma_{XY.Z}\Sigma_{Z}^{-1}\Sigma_{Z.XY}$
#
# ### Precision Matrix
# $P = \Sigma^{-1}$

# %%
def submatrix(Sigma, index_list):
    return Sigma[np.ix_(index_list,index_list)]

def conditional_cov(Sigma, targets, givens):
    subSigma_targets = submatrix(Sigma, targets)
    subSigma_givens = submatrix(Sigma, givens)
    subSigma_rest = Sigma[np.ix_(targets, givens)]
    
#     print 'Sigma\n', Sigma
#     print '\nsubSigma_targets \n', subSigma_targets
#     print '\n subSigma_givens\n', subSigma_givens
#     print '\n subSigma_rest \n', subSigma_rest
    
    return subSigma_targets - subSigma_rest.dot(np.linalg.pinv(subSigma_givens).dot(subSigma_rest.T))

def precision(Sigma):
    return np.linalg.inv(Sigma)

print conditional_cov(Sigma, [0], [1,2,3])
# Out:
# [[ 0.5]]

# %%
Sigma_XYdotZ = Sigma_XYZ[np.ix_([2],[0,1])]
Sigma_XYbarZ = Sigma_XY + np.dot(Sigma_XYdotZ.T, Sigma_XYdotZ)/sigma_Z**2
print 'Sigma XY given Z\n', Sigma_XYbarZ

Sigma_XYbarZ = submatrix(Sigma, [0,1]) - submatrix(Sigma,[3]).inv

Sigma_XYdotWZ = Sigma[np.ix_([2,3],[0,1])]
Sigma_XYbarWZ = Sigma_XY + np.dot(Sigma_XYdotWZ, np.dot(np.linalg.inv(Sigma_WZ), Sigma_XYdotWZ.T))
print '\nSigma XY given WZ\n', Sigma_XYbarWZ

P = np.linalg.pinv(Sigma)
print '\nP of XYWZ\n', P

P_XYZ = np.linalg.pinv(Sigma_XYZ)
print '\nP of XYZ\n', P_XYZ
# Out:
# Sigma XY given Z
# [[ 7 -3]
#  [-3  8]]
#
# Sigma XY given WZ
# [[  7.25   1.  ]
#  [  1.    27.  ]]
#
# P of XYWZ
# [[  2.00000000e+00  -1.00000000e+00  -1.00000000e+00  -3.00000000e+00]
#  [ -1.00000000e+00   1.00000000e+00   2.22044605e-16   2.00000000e+00]
#  [ -1.00000000e+00  -4.44089210e-16   2.00000000e+00   1.00000000e+00]
#  [ -3.00000000e+00   2.00000000e+00   1.00000000e+00   5.25000000e+00]]
#
# P of XYZ
# [[ 1.5  -1.   -2.5 ]
#  [-1.    1.    2.  ]
#  [-2.5   2.    4.75]]

# %%
np.dot(Sigma_XYdotWZ, np.dot(np.linalg.inv(Sigma_WZ), Sigma_XYdotWZ.T))
# Out:
# array([[  1.25,   3.  ],
#        [  3.  ,  20.  ]])

# %% [markdown]
# ## Test CMI formula with conditionally independent X, Y

# %%
n_samples = 1000

W = sts.norm.rvs(loc=5, scale = 1, size = [n_samples,1])
Z = sts.norm.rvs(loc=-5, scale = 2, size = [n_samples,1])
X = W + Z + sts.norm.rvs(loc=0, scale = 1, size = [n_samples,1])
Y = - 2*Z + sts.norm.rvs(loc=0, scale = 1, size = [n_samples,1])

data = np.hstack((X,Y,W,Z))

#                   X, Y, W, Z
Sigma = np.array([[ 6,-8,1, 4],
                  [-8,16,0,-8],
                  [ 1, 0,1, 0],
                  [ 4,-8,0, 4]])

# Sigma = np.cov(data.T)

Sigma_XYZ = Sigma[np.ix_([0,1,3],[0,1,3])]
Sigma_XWZ = Sigma[np.ix_([0,2,3],[0,2,3])]
Sigma_YWZ = Sigma[1:,1:]

Sigma_XY = Sigma[np.ix_([0,1],[0,1])]
Sigma_XZ = Sigma[np.ix_([0,3],[0,3])]
Sigma_YZ = Sigma[np.ix_([1,3],[1,3])]
Sigma_WZ = Sigma[2:,2:]

sigma_Z = Sigma[3,3]

CMI_XYZ = .5 * np.log( det(Sigma_XZ)*det(Sigma_YZ) / (det(Sigma_XYZ)*sigma_Z) )
CMI_XYZW = .5 * np.log( det(Sigma_XWZ)*det(Sigma_YWZ) / (det(Sigma)*det(Sigma_WZ)) )

print 'CMI(X,Y|Z)=', CMI_XYZ
print 'CMI(X,Y|Z,W)=', CMI_XYZW
# Out:
# CMI(X,Y|Z)= nan
# CMI(X,Y|Z,W)= nan
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:29: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:30: RuntimeWarning: invalid value encountered in double_scalars

# %%
Sigma_XYdotZ = Sigma_XYZ[np.ix_([2],[0,1])]
Sigma_XYbarZ = Sigma_XY + np.dot(Sigma_XYdotZ, Sigma_XYdotZ.T)/sigma_Z**2
print 'Sigma XY given Z\n', Sigma_XYbarZ

Sigma_XYdotWZ = Sigma[np.ix_([2,3],[0,1])]
Sigma_XYbarWZ = Sigma_XY + np.dot(Sigma_XYdotWZ, np.dot(np.linalg.inv(Sigma_WZ), Sigma_XYdotWZ.T))
print '\nSigma XY given WZ\n', Sigma_XYbarWZ

P = np.linalg.pinv(Sigma)
print '\nP of XYWZ\n', P

P_XYZ = np.linalg.pinv(Sigma_XYZ)
print '\nP of XYZ\n', P_XYZ
# Out:
# Sigma XY given Z
# [[11 -3]
#  [-3 21]]
#
# Sigma XY given WZ
# [[  7.  -4.]
#  [ -4.  48.]]
#
# P of XYWZ
# [[ 1.    0.4  -1.   -0.2 ]
#  [ 0.4   0.2  -0.4  -0.1 ]
#  [-1.   -0.4   2.    0.2 ]
#  [-0.2  -0.1   0.2   0.05]]
#
# P of XYZ
# [[ 0.5   0.2  -0.1 ]
#  [ 0.2   0.12 -0.06]
#  [-0.1  -0.06  0.03]]

# %% [markdown]
# ### TODO: Create a function for computing multivariate CMI for a DataFrame

# %%
det(Sigma_XYZ)
# Out:
# 12.0

# %% [markdown]
# ## Load data with Composer

# %%
import os
import pytest

import bayeslite
from bayeslite.sqlite3_util import sqlite3_quote_name as quote

import bdbcontrib
from bdbcontrib.metamodels.composer import Composer

os.environ['BAYESDB_WIZARD_MODE'] = '0'

bdb = bayeslite.bayesdb_open()
bayeslite.bayesdb_read_csv_file(bdb, 'lineargaussian', './lineargaussian.csv', header=True, create=True)
composer = Composer(n_samples=5)
bayeslite.bayesdb_register_metamodel(bdb, composer)


bdb.execute('''
CREATE GENERATOR gen FOR lineargaussian USING composer(
    crosscat (
        X NUMERICAL, Y NUMERICAL,
        W NUMERICAL, Z NUMERICAL
        ),
);''')

generator_id = bayeslite.core.bayesdb_get_generator(bdb, 'gen')
composer = bayeslite.core.bayesdb_generator_metamodel(bdb, generator_id)
bdb.execute('INITIALIZE 10 MODELS FOR gen')

c1 = bayeslite.core.bayesdb_table_column_number(bdb,'satellites','X')
c2 = bayeslite.core.bayesdb_table_column_number(bdb,'satellites','Y')
c3 = bayeslite.core.bayesdb_table_column_number(bdb,'satellites','Z')

MI_first = composer.column_mutual_information(bdb, generator_id, 0, c1, c2, numsamples=1000)
MI_second = composer.column_mutual_information(bdb, generator_id, 0, c2, c3, numsamples=100)

print MI_first, MI_second
